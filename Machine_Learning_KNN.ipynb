# %% [markdown]
# <a href="https://colab.research.google.com/github/martinondiwa/Acher-s-Post-KML/blob/main/Machine_Learning_KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ml
#supervised #unsupervised
#Machine with input and output labels #Input Data

# %%
#ml life cycle
#Get data.....>preprocess......>Split input/output........>train/test.....>algorithms...>prediction

# %%
#iris flower data

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv(
    "/content/drive/MyDrive/bts_01.csv"
)

# %%
df.head()
# Out:
#    S/N SITE ID      SITE NAME  Latitude  Longitude SITE TYPE   ROUTE  \
# 0  1.0  CEQ001     Juba Radio    4.8467    31.5964       HUB  ACCESS
# 1  2.0  CEQ002  Juba Military    4.8308    31.5953       HUB  ACCESS
# 2  3.0  CEQ003  Juba Hospital    4.8519    31.6097       HUB  ACCESS
# 3  4.0  CEQ004    Souk Hajjar    4.8633    31.5767       HUB  ACCESS
# 4  5.0  CEQ005         Nakoro    4.8489    31.5767  TERMINAL  ACCESS
#
#                                      DEPENDENT SITES  DEPENDENCY COUNT  \
# 0                 CEQ213,CEQ229,CEQ257,CEQ277,CEQ001               5.0
# 1                                      CEQ002,CEQ054               2.0
# 2                               CEQ003,CEQ216,CEQ048               3.0
# 3  CEQ151,CEQ160,CEQ175,CEQ174,CEQ226,CEQ004,CEQ2...               8.0
# 4                                             CEQ005               1.0
#
#   AFFECTED REGION        POWER SYSTEM  Unnamed: 11
# 0             CEQ  DG + Hybrid + Grid          NaN
# ...

# %%
df.columns
# Out:
# Index(['S/N', 'SITE ID', 'SITE NAME', 'Latitude', 'Longitude', 'SITE TYPE',
#        'ROUTE', 'DEPENDENT SITES', 'DEPENDENCY COUNT', 'AFFECTED REGION',
#        'POWER SYSTEM', 'Unnamed: 11'],
#       dtype='object')

# %%
x=df[['AFFECTED REGION', 'Latitude', 'Longitude', 'SITE TYPE', 'AFFECTED REGION']]
y=df['POWER SYSTEM']

# %%
x
# Out:
#     AFFECTED REGION  Latitude  Longitude SITE TYPE AFFECTED REGION
# 0               CEQ    4.8467    31.5964       HUB             CEQ
# 1               CEQ    4.8308    31.5953       HUB             CEQ
# 2               CEQ    4.8519    31.6097       HUB             CEQ
# 3               CEQ    4.8633    31.5767       HUB             CEQ
# 4               CEQ    4.8489    31.5767  TERMINAL             CEQ
# ..              ...       ...        ...       ...             ...
# 518             NaN       NaN        NaN       NaN             NaN
# 519             NaN       NaN        NaN       NaN             NaN
# 520             NaN       NaN        NaN       NaN             NaN
# 521             NaN       NaN        NaN       NaN             NaN
# 522             NaN       NaN        NaN       NaN             NaN
#
# [523 rows x 5 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier (n_neighbors=4)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=2,random_state=31)

# %%
knn.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2303676771.py in <cell line: 0>()
# ----> 1 knn.fit(x_train, y_train)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_classification.py in fit(self, X, y)
#     237             The fitted k-nearest neighbors classifier.
#     238         """
# --> 239         return self._fit(X, y)
#     240
#     241     def predict(self, X):
#
# /usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py in _fit(self, X, y)
#     476         if self.__sklearn_tags__().target_tags.required:
# ...
